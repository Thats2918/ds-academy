# %% [markdown]
# # 나의 첫 노트북
# 변수가 셀 사이에 유지되는 것을 확인한다.

# %%
a = 10

# %%
a * 2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a * 2
#
# NameError: name 'a' is not defined

# %%
b = 20

# %%
b * 20
# Out:
# 400
