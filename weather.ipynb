# %%
import requests
import pandas as pd

url = "https://api.open-meteo.com/v1/forecast"
params = {"latitude": 37.57, "longitude": 126.98, "hourly": "temperature_2m"}

# %%
df = pd.DataFrame(requests.get(url, params=params).json()["hourly"])
df.head()
# Out:
#                time  temperature_2m
# 0  2026-06-17T00:00            23.7
# 1  2026-06-17T01:00            24.7
# 2  2026-06-17T02:00            25.9
# 3  2026-06-17T03:00            27.5
# 4  2026-06-17T04:00            28.4
